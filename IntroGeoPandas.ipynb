# %% [markdown]
# <a href="https://colab.research.google.com/github/thamyrys-bl/example-geobr/blob/main/IntroGeoPandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Introdução ao Geopandas

# %%
# %%time
#Atualizando lista de pacotes, atualizando versões e instalando bibliotecas
# !apt update -q
# !apt upgrade -q
# !apt install gdal-bin python-gdal python3-gdal -q
# !apt install python3-rtree -q
# !pip install geopandas==0.10.0
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Get:2 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Hit:4 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Hit:5 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease
# Hit:6 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:8 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:9 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [2,093 kB]
# Get:10 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [1,073 kB]
# Get:11 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Get:12 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,938 kB]
# ...

# %%
# !pip install descartes -q

# %%
# %matplotlib inline
import geopandas as gpd

# %%
rj= gpd.read_file('/content/33MUE250GC_SIR.shp') #usando os dados

# %%
type(rj) #vendo o tipo de dado
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
rj #dando uma olhada nos dados
# Out:
#       ID CD_GEOCODM          NM_MUNICIP  \
# 0   1468    3300100      ANGRA DOS REIS
# 1   1469    3300159             APERIBÉ
# 2   1470    3300209            ARARUAMA
# 3   1471    3300225               AREAL
# 4   1472    3300233  ARMAÇÃO DOS BÚZIOS
# ..   ...        ...                 ...
# 87  1555    3306008           TRÊS RIOS
# 88  1556    3306107             VALENÇA
# 89  1557    3306156           VARRE-SAI
# 90  1558    3306206           VASSOURAS
# 91  1559    3306305       VOLTA REDONDA
#
#                                              geometry
# 0   MULTIPOLYGON (((-44.33208 -23.02384, -44.33221...
# 1   POLYGON ((-42.08950 -21.62893, -42.08912 -21.6...
# 2   POLYGON ((-42.22526 -22.59253, -42.22521 -22.5...
# 3   POLYGON ((-43.16007 -22.20005, -43.16003 -22.1...
# 4   MULTIPOLYGON (((-41.98427 -22.74458, -41.98296...
# ..                                                ...
# 87  POLYGON ((-43.13666 -22.10933, -43.13182 -22.1...
# ...

# %%
rj.plot()

# %%
rj.plot(color='white', edgecolor='black', figsize=(15,8))

# %%
from shapely.geometry import Polygon, Point, LineString, MultiPolygon

# %%
p1= Polygon([(0,0), (1,0), (1,1), (0,1)])
p2= Polygon([(0,0), (1,0), (1,1)])

p3= Polygon([(2,0), (3,0), (3,1),(2,1)])

p4= LineString([(0,1),(3,0),(1,1)])
p5= Point(0.5, 0.5)

p6= Polygon([(1,0),(1.5, 0.4),(2,0)])
p7= Polygon([(1,1),(1.5, 0.6),(2,1)])

p8= MultiPolygon([p6, p7])

g= gpd.GeoSeries([p1, p2, p3, p4, p5, p8])
g.plot(cmap='tab10', figsize=(15,8))

# %%
g
# Out:
# 0    POLYGON ((0.00000 0.00000, 1.00000 0.00000, 1....
# 1    POLYGON ((0.00000 0.00000, 1.00000 0.00000, 1....
# 2    POLYGON ((2.00000 0.00000, 3.00000 0.00000, 3....
# 3    LINESTRING (0.00000 1.00000, 3.00000 0.00000, ...
# 4                              POINT (0.50000 0.50000)
# 5    MULTIPOLYGON (((1.00000 0.00000, 1.50000 0.400...
# dtype: geometry

# %%
#Exercicio
import geopandas as gpd
from shapely.geometry import Polygon, Point, LineString, MultiPolygon

# %%
p1 = Polygon([(0, 0), (2, 1), (2, 0), (0, 1)])

g = gpd.GeoSeries([p1])
g.plot(cmap='tab10', figsize=(15,8))

# %%
figuras = []
for i in [0.5, 0.2, 0]:
    figuras.append(Polygon([(0 - i, 0 + i),
                            (1 - i, 0 - i),
                            (1 + i, 1 - i),
                            (0 + i, 1 + i)]))

g = gpd.GeoSeries(figuras)
g.plot(cmap='Spectral', figsize=(15,8))

# %%
p1 = Polygon([(0, 0), (1, 0.5), (0, 1)])
p2 = Polygon([(2, 0), (1, 0.5), (2, 1)])

g = gpd.GeoSeries([p1, p2])
g.plot(cmap='tab10', figsize=(15,8))

# %%
p1 = Point(0.5, 0.5).buffer(0.5)
p2 = MultiPolygon([Point(0.25, 0.6).buffer(0.1), 
                    Point(0.75, 0.6).buffer(0.1)])
p3 = MultiPolygon([Point(0.25, 0.6).buffer(0.02),
                    Point(0.75, 0.6).buffer(0.02)])
p4 = LineString([(0.2, 0.25), (0.8, 0.25)])

g = gpd.GeoSeries([p1, p2, p3, p4])
g.plot(cmap='Wistia', figsize=(15,8))

# %%
#Instalar o GeoPandas
#Plotar um mapa com os municípios do Rio de Janeiro
#Explorar e plotar polígonos, com os shapes Polygon, Point, LineString e MultiPolygon

# %% [markdown]
# # Do DataFrame ao GeoDataFrame

# %%
# Criando Shapefiles
# %matplotlib inline
import geopandas as gpd

# %%
rj= gpd.read_file('/content/33MUE250GC_SIR.shp')

# %%
rj
# Out:
#       ID CD_GEOCODM          NM_MUNICIP  \
# 0   1468    3300100      ANGRA DOS REIS
# 1   1469    3300159             APERIBÉ
# 2   1470    3300209            ARARUAMA
# 3   1471    3300225               AREAL
# 4   1472    3300233  ARMAÇÃO DOS BÚZIOS
# ..   ...        ...                 ...
# 87  1555    3306008           TRÊS RIOS
# 88  1556    3306107             VALENÇA
# 89  1557    3306156           VARRE-SAI
# 90  1558    3306206           VASSOURAS
# 91  1559    3306305       VOLTA REDONDA
#
#                                              geometry
# 0   MULTIPOLYGON (((-44.33208 -23.02384, -44.33221...
# 1   POLYGON ((-42.08950 -21.62893, -42.08912 -21.6...
# 2   POLYGON ((-42.22526 -22.59253, -42.22521 -22.5...
# 3   POLYGON ((-43.16007 -22.20005, -43.16003 -22.1...
# 4   MULTIPOLYGON (((-41.98427 -22.74458, -41.98296...
# ..                                                ...
# 87  POLYGON ((-43.13666 -22.10933, -43.13182 -22.1...
# ...

# %%
rj.plot(color='white', edgecolor='black', figsize=(20,10))

# %%
#Modificando o GeoDataFrame

rj= rj[rj['NM_MUNICIP']== 'RIO DE JANEIRO']

# %%
rj
# Out:
#       ID CD_GEOCODM      NM_MUNICIP  \
# 67  1535    3304557  RIO DE JANEIRO
#
#                                              geometry
# 67  MULTIPOLYGON (((-43.12376 -22.80712, -43.12380...

# %%
rj.plot(color='orange', edgecolor='black', figsize=(20,10))

# %%
#Salvando
import os

dir= '../GEOPANDAS/Mapas/Mapas/RJ-MUNIC'
if not os.path.exists(dir):
    os.makedirs(dir)

# %%
rj.to_file(dir + '/RJ-MUNIC.shp')
